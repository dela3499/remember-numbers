# %% [markdown]
# Some resources for the project
#
#  - http://www.speech.cs.cmu.edu/cgi-bin/cmudict
#  - http://www.nltk.org/book/ch11.html
#  - https://en.wikipedia.org/wiki/Mnemonic_major_system
#  - https://github.com/rhdunn/cmudict-tools

# %%
execfile('/home/carlos/projects/utils/utils.py')

# %%
def parse_mnemonic_line(line):
    phoneme, value = line.split(" ")
    return (phoneme, value)

mnemonic_map = tz.thread_last(
    "./mnemonics.txt",
    read_lines,
    (map, parse_mnemonic_line),
    dict
)

mnemonic_phonemes = mnemonic_map.keys()
illegal_phonemes = [phoneme for phoneme, value in mnemonic_map.items() if value == "X"]
legal_phonemes = [phoneme for phoneme, value in mnemonic_map.items() if value != "X"]

# %%
def parse_cmu_line(line):
    chunks = line.split()
    word = strip_suffix(chunks[0], ["(1)", "(2)", "(3)", "(4)"])
    drop_numbers = lambda string: "".join([char for char in string if char not in "0123456789"])
    is_consonant = lambda phoneme: phoneme in mnemonic_phonemes
    
    all_phonemes = map(drop_numbers, chunks[1:]) # emphasis annotations aren't needed here
    phonemes = filter(is_consonant, all_phonemes) # vowels aren't part of the mnemonic
    numbers = [mnemonic_map[phoneme] for phoneme in phonemes]
    
    if (nvenn(phonemes, illegal_phonemes)[1] > 0) or (nvenn(phonemes, legal_phonemes)[1] < 1):
        return [] # ignore words with illegal phonemes, or which contain no allowed phonemes
    else: 
        return [{"word": word, "phonemes": phonemes, "all_phonemes": all_phonemes, "numbers": numbers}]
    
cmu = tz.thread_last(
    './cmudict.txt',
    read_file,
    split_lines,
    (filter, lambda line: not line.startswith(";;;")),
    (tz.mapcat, parse_cmu_line),
    list
)

# %%
def search_words(f): 
    return [entry for entry in cmu if f(entry['word'])]

def search_numbers(f): 
    return [entry for entry in cmu if f(entry['numbers'])]

def search_phonemes(f): 
    return [entry for entry in cmu if f(entry['phonemes'])]

# %%
def partition(n, seq):
    if len(seq) <= n:
        return [seq]
    else: 
        return [seq[:n]] + partition(n, seq[n:])
    
def translate(numbers):
    return tz.thread_last(
        numbers, 
        str,
        list,
        (partition, 3),
        (map, lambda query_numbers: search_numbers(lambda numbers: numbers == query_numbers)),
        list
    )
translate(1)
# Out:
# [[{'all_phonemes': ['AE', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AD'},
#   {'all_phonemes': ['EY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADA'},
#   {'all_phonemes': ['AE', 'D', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADAH'},
#   {'all_phonemes': ['AH', 'D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADAY'},
#   {'all_phonemes': ['AE', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADD'},
#   {'all_phonemes': ['AA', 'D', 'IY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADDEO'},
#   {'all_phonemes': ['AE', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADDIE'},
#   {'all_phonemes': ['AE', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADDY'},
#   {'all_phonemes': ['EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADE'},
#   {'all_phonemes': ['AH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADEE'},
#   {'all_phonemes': ['EY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADEY'},
#   {'all_phonemes': ['AA', 'D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADIA'},
#   {'all_phonemes': ['AH', 'D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADIEU'},
#   {'all_phonemes': ['AH', 'D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADO'},
#   {'all_phonemes': ['EY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ADY'},
#   {'all_phonemes': ['AH', 'HH', 'EH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AHEAD'},
#   {'all_phonemes': ['EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AID'},
#   {'all_phonemes': ['AY', 'IY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AIDA'},
#   {'all_phonemes': ['EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AIDE'},
#   {'all_phonemes': ['AH', 'HH', 'IY', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AJITO'},
#   {'all_phonemes': ['AE', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AT'},
#   {'all_phonemes': ['AA', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ATA'},
#   {'all_phonemes': ['EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ATE'},
#   {'all_phonemes': ['AE', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ATTA'},
#   {'all_phonemes': ['AE', 'T', 'AA', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ATTAWAY'},
#   {'all_phonemes': ['AE', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ATTIE'},
#   {'all_phonemes': ['AO', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AUD'},
#   {'all_phonemes': ['AO', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AUDI'},
#   {'all_phonemes': ['AW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AUDI'},
#   {'all_phonemes': ['AO', 'D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AUDIA'},
#   {'all_phonemes': ['AA', 'D', 'IY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AUDIO'},
#   {'all_phonemes': ['AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AUGHT'},
#   {'all_phonemes': ['AO', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AUTO'},
#   {'all_phonemes': ['AH', 'W', 'AA', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AWAD'},
#   {'all_phonemes': ['AH', 'W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AWAIT'},
#   {'all_phonemes': ['AO', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AWED'},
#   {'all_phonemes': ['AH', 'W', 'EY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AWEIDA'},
#   {'all_phonemes': ['AH', 'W', 'AY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AWEIDA'},
#   {'all_phonemes': ['EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AYDT'},
#   {'all_phonemes': ['AY', 'AA', 'D', 'Y', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AYODHYA'},
#   {'all_phonemes': ['EY', 'AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'AYOTTE'},
#   {'all_phonemes': ['AY', 'AA', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AYYAD'},
#   {'all_phonemes': ['AY', 'AE', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'AYYAD'},
#   {'all_phonemes': ['D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'D'},
#   {'all_phonemes': ['D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'D.'},
#   {'all_phonemes': ['D', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DA'},
#   {'all_phonemes': ['D', 'IY', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DA'},
#   {'all_phonemes': ['D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAE'},
#   {'all_phonemes': ['D', 'EY', 'W', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAEWOO'},
#   {'all_phonemes': ['D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAH'},
#   {'all_phonemes': ['D', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAI'},
#   {'all_phonemes': ['D', 'AY', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAIEI'},
#   {'all_phonemes': ['D', 'EY', 'W', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAIWA'},
#   {'all_phonemes': ['D', 'AW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAO'},
#   {'all_phonemes': ['D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAU'},
#   {'all_phonemes': ['D', 'AO'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAW'},
#   {'all_phonemes': ['D', 'AO'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAWE'},
#   {'all_phonemes': ['D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAY'},
#   {'all_phonemes': ['D', 'AY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAYA'},
#   {'all_phonemes': ['D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DAYE'},
#   {'all_phonemes': ['D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DE'},
#   {'all_phonemes': ['D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DE'},
#   {'all_phonemes': ['D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DE'},
#   {'all_phonemes': ['D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEA'},
#   {'all_phonemes': ['D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEE'},
#   {'all_phonemes': ['D', 'IY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEO'},
#   {'all_phonemes': ['D', 'IH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DES'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEUX'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEW'},
#   {'all_phonemes': ['D', 'UW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEWEY'},
#   {'all_phonemes': ['D', 'UW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEWY'},
#   {'all_phonemes': ['D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEY'},
#   {'all_phonemes': ['D', 'EY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEYO'},
#   {'all_phonemes': ['D', 'EY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DEYOE'},
#   {'all_phonemes': ['D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DHIA'},
#   {'all_phonemes': ['D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DI'},
#   {'all_phonemes': ['D', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DI'},
#   {'all_phonemes': ['D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DIA'},
#   {'all_phonemes': ['D', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DIE'},
#   {'all_phonemes': ['D', 'IY', 'W', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DIWA'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DO'},
#   {'all_phonemes': ['D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOE'},
#   {'all_phonemes': ['D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOH'},
#   {'all_phonemes': ['D', 'OW', 'HH', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOHA'},
#   {'all_phonemes': ['D', 'OY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOI'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOO'},
#   {'all_phonemes': ['D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOUGH'},
#   {'all_phonemes': ['D', 'OW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOUGHY'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOUWE'},
#   {'all_phonemes': ['D', 'AW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOW'},
#   {'all_phonemes': ['D', 'AW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOWE'},
#   {'all_phonemes': ['D', 'AW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DOWIE'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DU'},
#   {'all_phonemes': ['D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DU'},
#   {'all_phonemes': ['D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUE'},
#   {'all_phonemes': ['D', 'Y', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUE'},
#   {'all_phonemes': ['D', 'UW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUEY'},
#   {'all_phonemes': ['D', 'Y', 'UW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUEY'},
#   {'all_phonemes': ['D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUH'},
#   {'all_phonemes': ['D', 'UW', 'HH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUHE'},
#   {'all_phonemes': ['D', 'IY', 'Y', 'UW', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUI'},
#   {'all_phonemes': ['D', 'UW', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUO'},
#   {'all_phonemes': ['D', 'UW', 'W'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DUWE'},
#   {'all_phonemes': ['D', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'DYE'},
#   {'all_phonemes': ['IY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EADDY'},
#   {'all_phonemes': ['IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EADE'},
#   {'all_phonemes': ['EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EADIE'},
#   {'all_phonemes': ['IY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EADY'},
#   {'all_phonemes': ['IY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'EAT'},
#   {'all_phonemes': ['EH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ED'},
#   {'all_phonemes': ['IY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDA'},
#   {'all_phonemes': ['EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDDIE'},
#   {'all_phonemes': ['EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDDY'},
#   {'all_phonemes': ['IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDE'},
#   {'all_phonemes': ['IY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDI'},
#   {'all_phonemes': ['EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDIE'},
#   {'all_phonemes': ['IY', 'D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDO'},
#   {'all_phonemes': ['EH', 'D', 'Y', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDU'},
#   {'all_phonemes': ['IY', 'D', 'IY', 'Y', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDU'},
#   {'all_phonemes': ['EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDYE'},
#   {'all_phonemes': ['IY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EDYE'},
#   {'all_phonemes': ['EH', 'HH', 'AH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EHUD'},
#   {'all_phonemes': ['AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EID'},
#   {'all_phonemes': ['AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EIDE'},
#   {'all_phonemes': ['EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'EIGHT'},
#   {'all_phonemes': ['EY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'EIGHTY'},
#   {'all_phonemes': ['EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ET'},
#   {'all_phonemes': ['EH', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ETTA'},
#   {'all_phonemes': ['EH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ETTIE'},
#   {'all_phonemes': ['EH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ETTY'},
#   {'all_phonemes': ['Y', 'UW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EUDY'},
#   {'all_phonemes': ['EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EYDE'},
#   {'all_phonemes': ['EY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EYDIE'},
#   {'all_phonemes': ['AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'EYED'},
#   {'all_phonemes': ['HH', 'AE', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAD'},
#   {'all_phonemes': ['HH', 'AA', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADA'},
#   {'all_phonemes': ['HH', 'AA', 'D', 'AH', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADAWAY'},
#   {'all_phonemes': ['HH', 'AE', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADD'},
#   {'all_phonemes': ['HH', 'AE', 'D', 'AH', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADDAWAY'},
#   {'all_phonemes': ['HH', 'AE', 'D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADDOW'},
#   {'all_phonemes': ['HH', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADE'},
#   {'all_phonemes': ['HH', 'AH', 'D', 'OY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HADOYA'},
#   {'all_phonemes': ['HH', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAID'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAIDA'},
#   {'all_phonemes': ['HH', 'EY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAIDEE'},
#   {'all_phonemes': ['HH', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAIGHT'},
#   {'all_phonemes': ['HH', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAIT'},
#   {'all_phonemes': ['HH', 'EY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAITI'},
#   {'all_phonemes': ['HH', 'AA', 'Y', 'D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAJDU'},
#   {'all_phonemes': ['HH', 'AE', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAT'},
#   {'all_phonemes': ['HH', 'AA', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATA'},
#   {'all_phonemes': ['HH', 'AE', 'T', 'AH', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATAWAY'},
#   {'all_phonemes': ['HH', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATE'},
#   {'all_phonemes': ['HH', 'AE', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATT'},
#   {'all_phonemes': ['HH', 'AE', 'T', 'AH', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATTAWAY'},
#   {'all_phonemes': ['HH', 'AE', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATTIE'},
#   {'all_phonemes': ['HH', 'AE', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HATTY'},
#   {'all_phonemes': ['HH', 'AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAUGHT'},
#   {'all_phonemes': ['HH', 'AO', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAUGHTY'},
#   {'all_phonemes': ['HH', 'AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAUT'},
#   {'all_phonemes': ['HH', 'OW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAUTE'},
#   {'all_phonemes': ['HH', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HAUTE'},
#   {'all_phonemes': ['HH', 'EY', 'D', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAYDU'},
#   {'all_phonemes': ['HH', 'EY', 'W', 'UH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HAYWOOD'},
#   {'all_phonemes': ['HH', 'IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "HE'D"},
#   {'all_phonemes': ['HH', 'EH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEAD'},
#   {'all_phonemes': ['HH', 'EH', 'D', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEADWAY'},
#   {'all_phonemes': ['HH', 'EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEADY'},
#   {'all_phonemes': ['HH', 'IY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HEAT'},
#   {'all_phonemes': ['HH', 'EY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEDA'},
#   {'all_phonemes': ['HH', 'EH', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEDDA'},
#   {'all_phonemes': ['HH', 'EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEDDY'},
#   {'all_phonemes': ['HH', 'EH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEDI'},
#   {'all_phonemes': ['HH', 'IY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEDY'},
#   {'all_phonemes': ['HH', 'IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEED'},
#   {'all_phonemes': ['HH', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEID'},
#   {'all_phonemes': ['HH', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEIDE'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEIDI'},
#   {'all_phonemes': ['HH', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HEIGHT'},
#   {'all_phonemes': ['HH', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HEIT'},
#   {'all_phonemes': ['HH', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HETT'},
#   {'all_phonemes': ['HH', 'EH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HETTI'},
#   {'all_phonemes': ['HH', 'EH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HETTIE'},
#   {'all_phonemes': ['HH', 'EH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HETTY'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HEWETT'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HEWITT'},
#   {'all_phonemes': ['HH', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEYD'},
#   {'all_phonemes': ['HH', 'EY', 'D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEYDAY'},
#   {'all_phonemes': ['HH', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEYDE'},
#   {'all_phonemes': ['HH', 'EY', 'W', 'UH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HEYWOOD'},
#   {'all_phonemes': ['HH', 'AY', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HIATT'},
#   {'all_phonemes': ['HH', 'IH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HID'},
#   {'all_phonemes': ['HH', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HIDE'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'AH', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HIDEAWAY'},
#   {'all_phonemes': ['HH', 'IH', 'D', 'EY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HIDEO'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HIDY'},
#   {'all_phonemes': ['HH', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HIETT'},
#   {'all_phonemes': ['HH', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HIGHT'},
#   {'all_phonemes': ['HH', 'AY', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HIOTT'},
#   {'all_phonemes': ['HH', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HIT'},
#   {'all_phonemes': ['HH', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HITE'},
#   {'all_phonemes': ['HH', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HITT'},
#   {'all_phonemes': ['HH', 'IH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HITTY'},
#   {'all_phonemes': ['HH', 'AA', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HODDE'},
#   {'all_phonemes': ['HH', 'OW', 'D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HODO'},
#   {'all_phonemes': ['HH', 'OY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOIT'},
#   {'all_phonemes': ['HH', 'OY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOITY'},
#   {'all_phonemes': ['HH', 'UH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HOOD'},
#   {'all_phonemes': ['HH', 'UW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOOT'},
#   {'all_phonemes': ['HH', 'UW', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOOTIE'},
#   {'all_phonemes': ['HH', 'AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOT'},
#   {'all_phonemes': ['HH', 'OW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOTE'},
#   {'all_phonemes': ['HH', 'AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOTT'},
#   {'all_phonemes': ['HH', 'AW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HOUDE'},
#   {'all_phonemes': ['HH', 'AW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOUT'},
#   {'all_phonemes': ['HH', 'AW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "HOW'D"},
#   {'all_phonemes': ['HH', 'AW', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOWAT'},
#   {'all_phonemes': ['HH', 'AW', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOWATT'},
#   {'all_phonemes': ['HH', 'AW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HOWDY'},
#   {'all_phonemes': ['HH', 'AW', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOWITT'},
#   {'all_phonemes': ['HH', 'OY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HOYT'},
#   {'all_phonemes': ['HH', 'AH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HUD'},
#   {'all_phonemes': ['HH', 'UW', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HUDA'},
#   {'all_phonemes': ['HH', 'AH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HUDDIE'},
#   {'all_phonemes': ['HH', 'AH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HUDDY'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HUDY'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HUED'},
#   {'all_phonemes': ['HH', 'UW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUETT'},
#   {'all_phonemes': ['HH', 'UW', 'EH', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUETTA'},
#   {'all_phonemes': ['HH', 'UW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUETTE'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUGHETT'},
#   {'all_phonemes': ['Y', 'UW', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUGHETT'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUGHETTE'},
#   {'all_phonemes': ['Y', 'UW', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUGHETTE'},
#   {'all_phonemes': ['HH', 'UW', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUHTA'},
#   {'all_phonemes': ['HH', 'UW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUITT'},
#   {'all_phonemes': ['HH', 'AH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HULDIE'},
#   {'all_phonemes': ['HH', 'Y', 'UW', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUOT'},
#   {'all_phonemes': ['HH', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUT'},
#   {'all_phonemes': ['HH', 'UW', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUTA'},
#   {'all_phonemes': ['HH', 'UW', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUTO'},
#   {'all_phonemes': ['HH', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUTT'},
#   {'all_phonemes': ['HH', 'UW', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUTTO'},
#   {'all_phonemes': ['HH', 'UW', 'T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUTU'},
#   {'all_phonemes': ['HH', 'AY', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HUYETT'},
#   {'all_phonemes': ['HH', 'AY', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'HYATT'},
#   {'all_phonemes': ['HH', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HYDE'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HYDEA'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'EY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HYDEA'},
#   {'all_phonemes': ['HH', 'AY', 'D', 'EY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'HYDEIA'},
#   {'all_phonemes': ['AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "I'D"},
#   {'all_phonemes': ['IH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ID'},
#   {'all_phonemes': ['AY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ID'},
#   {'all_phonemes': ['AY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IDA'},
#   {'all_phonemes': ['AY', 'D', 'AH', 'HH', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IDAHO'},
#   {'all_phonemes': ['AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IDE'},
#   {'all_phonemes': ['AY', 'D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IDEA'},
#   {'all_phonemes': ['IY', 'D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IDO'},
#   {'all_phonemes': ['IH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IHDE'},
#   {'all_phonemes': ['IY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'IIDA'},
#   {'all_phonemes': ['AY', 'OW', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'IOTA'},
#   {'all_phonemes': ['AY', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'IOTT'},
#   {'all_phonemes': ['IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'IT'},
#   {'all_phonemes': ['IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'IT'},
#   {'all_phonemes': ['AY', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ITA'},
#   {'all_phonemes': ['AY', 'T', 'IY', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ITA'},
#   {'all_phonemes': ['IY', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ITO'},
#   {'all_phonemes': ['IY', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ITO'},
#   {'all_phonemes': ['IY', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ITOH'},
#   {'all_phonemes': ['IH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'ITTY'},
#   {'all_phonemes': ['IY', 'W', 'AA', 'T', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'IWATA'},
#   {'all_phonemes': ['AY', 'W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'IWATE'},
#   {'all_phonemes': ['EH', 'T', 'IY', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'LTI'},
#   {'all_phonemes': ['OW', 'D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "O'DAY"},
#   {'all_phonemes': ['OW', 'D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "O'DEA"},
#   {'all_phonemes': ['OW', 'EY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'OAD'},
#   {'all_phonemes': ['OW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OAT'},
#   {'all_phonemes': ['OW', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODA'},
#   {'all_phonemes': ['OW', 'D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODAY'},
#   {'all_phonemes': ['AA', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODD'},
#   {'all_phonemes': ['AA', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODDI'},
#   {'all_phonemes': ['OW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODDI'},
#   {'all_phonemes': ['AA', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODDY'},
#   {'all_phonemes': ['OW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODE'},
#   {'all_phonemes': ['AA', 'D', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'ODEA'},
#   {'all_phonemes': ['OW', 'Y', 'EY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'OJEDA'},
#   {'all_phonemes': ['AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OT'},
#   {'all_phonemes': ['OW', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OT'},
#   {'all_phonemes': ['OW', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTA'},
#   {'all_phonemes': ['OW', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTEY'},
#   {'all_phonemes': ['AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTT'},
#   {'all_phonemes': ['AA', 'T', 'AH', 'W', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTTAWA'},
#   {'all_phonemes': ['AA', 'T', 'AH', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTTAWAY'},
#   {'all_phonemes': ['AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTTE'},
#   {'all_phonemes': ['AA', 'T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OTTO'},
#   {'all_phonemes': ['AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OUGHT'},
#   {'all_phonemes': ['AO', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OUGHTA'},
#   {'all_phonemes': ['AW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OUT'},
#   {'all_phonemes': ['UW', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OUTTA'},
#   {'all_phonemes': ['AW', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OUTTA'},
#   {'all_phonemes': ['AW', 'T', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'OUTWEIGH'},
#   {'all_phonemes': ['OW', 'AA', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'OWADA'},
#   {'all_phonemes': ['OW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'OWED'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'PTY'},
#   {'all_phonemes': ['T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'T'},
#   {'all_phonemes': ['T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'T.'},
#   {'all_phonemes': ['T', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TA'},
#   {'all_phonemes': ['T', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAE'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAE'},
#   {'all_phonemes': ['T', 'AY', 'W', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAEWOO'},
#   {'all_phonemes': ['T', 'AE', 'HH', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAHOE'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAI'},
#   {'all_phonemes': ['T', 'AY', 'Y', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAIYO'},
#   {'all_phonemes': ['T', 'AW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAO'},
#   {'all_phonemes': ['D', 'AW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'TAO'},
#   {'all_phonemes': ['T', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TAY'},
#   {'all_phonemes': ['T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TE'},
#   {'all_phonemes': ['T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TEA'},
#   {'all_phonemes': ['T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TEE'},
#   {'all_phonemes': ['T', 'EY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TEO'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TEW'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'THAI'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'THUY'},
#   {'all_phonemes': ['T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TI'},
#   {'all_phonemes': ['T', 'IY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TIA'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TIE'},
#   {'all_phonemes': ['T', 'IY', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TIEU'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TO'},
#   {'all_phonemes': ['T', 'IH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TO'},
#   {'all_phonemes': ['T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TO'},
#   {'all_phonemes': ['T', 'OW', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOA'},
#   {'all_phonemes': ['T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOE'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOO'},
#   {'all_phonemes': ['T', 'UW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOOHEY'},
#   {'all_phonemes': ['T', 'AH', 'HH', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOUHEY'},
#   {'all_phonemes': ['T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOW'},
#   {'all_phonemes': ['T', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOWE'},
#   {'all_phonemes': ['T', 'OW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOWEY'},
#   {'all_phonemes': ['T', 'OY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOY'},
#   {'all_phonemes': ['T', 'OY', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOYA'},
#   {'all_phonemes': ['T', 'OY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOYE'},
#   {'all_phonemes': ['T', 'OW', 'Y', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOYO'},
#   {'all_phonemes': ['T', 'OY', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TOYOO'},
#   {'all_phonemes': ['T', 'W', 'AA'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TROIS'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TU'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TUE'},
#   {'all_phonemes': ['T', 'UW', 'HH', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TUOHEY'},
#   {'all_phonemes': ['T', 'UW', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TUOHY'},
#   {'all_phonemes': ['T', 'UW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TWO'},
#   {'all_phonemes': ['T', 'UW', 'W', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TWO-WAY'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TY'},
#   {'all_phonemes': ['T', 'AY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TYE'},
#   {'all_phonemes': ['T', 'AY', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'TYO'},
#   {'all_phonemes': ['UW', 'D', 'EY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UDAY'},
#   {'all_phonemes': ['UW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UDE'},
#   {'all_phonemes': ['UW', 'D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UDO'},
#   {'all_phonemes': ['Y', 'UW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UDY'},
#   {'all_phonemes': ['W', 'EH', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UEDA'},
#   {'all_phonemes': ['UW', 'EY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UEDA'},
#   {'all_phonemes': ['AH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UHDE'},
#   {'all_phonemes': ['UW', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UHDE'},
#   {'all_phonemes': ['Y', 'UW', 'T', 'AO'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'UTAH'},
#   {'all_phonemes': ['AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'UTT'},
#   {'all_phonemes': ['AY', 'IY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'UYEDA'},
#   {'all_phonemes': ['W', 'UW', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'W00T'},
#   {'all_phonemes': ['W', 'AA', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WAD'},
#   {'all_phonemes': ['W', 'AA', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WADA'},
#   {'all_phonemes': ['W', 'AA', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WADDIE'},
#   {'all_phonemes': ['W', 'AA', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WADDY'},
#   {'all_phonemes': ['W', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WADE'},
#   {'all_phonemes': ['W', 'AA', 'HH', 'IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WAHID'},
#   {'all_phonemes': ['W', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WAID'},
#   {'all_phonemes': ['W', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WAIDE'},
#   {'all_phonemes': ['W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WAIT'},
#   {'all_phonemes': ['W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WAITE'},
#   {'all_phonemes': ['W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WAITT'},
#   {'all_phonemes': ['W', 'AO', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WAT'},
#   {'all_phonemes': ['W', 'AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WATT'},
#   {'all_phonemes': ['W', 'AA', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WATTIE'},
#   {'all_phonemes': ['W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WAYT'},
#   {'all_phonemes': ['W', 'IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "WE'D"},
#   {'all_phonemes': ['W', 'EH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WED'},
#   {'all_phonemes': ['W', 'EH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEDD'},
#   {'all_phonemes': ['W', 'EH', 'D', 'AW', 'W', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEDOWEE'},
#   {'all_phonemes': ['W', 'IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEED'},
#   {'all_phonemes': ['W', 'IY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEEDY'},
#   {'all_phonemes': ['W', 'EH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEHDE'},
#   {'all_phonemes': ['W', 'AY', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEIDE'},
#   {'all_phonemes': ['W', 'EY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WEIGHED'},
#   {'all_phonemes': ['W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WEIGHT'},
#   {'all_phonemes': ['W', 'EY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WEIGHTY'},
#   {'all_phonemes': ['W', 'EY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WEIGHTY'},
#   {'all_phonemes': ['W', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WET'},
#   {'all_phonemes': ['W', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHAT'},
#   {'all_phonemes': ['HH', 'W', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHAT'},
#   {'all_phonemes': ['W', 'EY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHATE'},
#   {'all_phonemes': ['W', 'IY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHEAT'},
#   {'all_phonemes': ['HH', 'W', 'IY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHEAT'},
#   {'all_phonemes': ['W', 'IY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHEATIE'},
#   {'all_phonemes': ['HH', 'W', 'IY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHEATIE'},
#   {'all_phonemes': ['W', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHET'},
#   {'all_phonemes': ['HH', 'W', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHET'},
#   {'all_phonemes': ['W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHIT'},
#   {'all_phonemes': ['HH', 'W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHIT'},
#   {'all_phonemes': ['W', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITE'},
#   {'all_phonemes': ['HH', 'W', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITE'},
#   {'all_phonemes': ['W', 'AY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITEY'},
#   {'all_phonemes': ['HH', 'W', 'AY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITEY'},
#   {'all_phonemes': ['HH', 'W', 'AY', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITEY'},
#   {'all_phonemes': ['W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITT'},
#   {'all_phonemes': ['HH', 'W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITT'},
#   {'all_phonemes': ['W', 'IH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITTY'},
#   {'all_phonemes': ['HH', 'W', 'IH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHITTY'},
#   {'all_phonemes': ['HH', 'UW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "WHO'D"},
#   {'all_phonemes': ['W', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "WHY'D"},
#   {'all_phonemes': ['HH', 'W', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "WHY'D"},
#   {'all_phonemes': ['W', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHYTE'},
#   {'all_phonemes': ['HH', 'W', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WHYTE'},
#   {'all_phonemes': ['W', 'AY', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WIATT'},
#   {'all_phonemes': ['W', 'AY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WIDE'},
#   {'all_phonemes': ['W', 'IH', 'D', 'OW'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WIDOW'},
#   {'all_phonemes': ['W', 'IY', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WIED'},
#   {'all_phonemes': ['W', 'AY', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WIGHT'},
#   {'all_phonemes': ['W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WIT'},
#   {'all_phonemes': ['W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WITT'},
#   {'all_phonemes': ['W', 'IH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WITTE'},
#   {'all_phonemes': ['W', 'IH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WITTY'},
#   {'all_phonemes': ['W', 'UH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WOOD'},
#   {'all_phonemes': ['W', 'UH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WOODIE'},
#   {'all_phonemes': ['W', 'UH', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WOODY'},
#   {'all_phonemes': ['W', 'UW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WOOED'},
#   {'all_phonemes': ['W', 'UH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WOULD'},
#   {'all_phonemes': ['W', 'AW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WOWED'},
#   {'all_phonemes': ['W', 'OY', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'WUYDA'},
#   {'all_phonemes': ['W', 'AY', 'AH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'WYATT'},
#   {'all_phonemes': ['Y', 'AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'YACHT'},
#   {'all_phonemes': ['Y', 'AA', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'YADDA'},
#   {'all_phonemes': ['Y', 'EH', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'YEDDA'},
#   {'all_phonemes': ['Y', 'AH', 'HH', 'UW', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'YEHUDA'},
#   {'all_phonemes': ['Y', 'EY', 'HH', 'UW', 'D', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'YEHUDI'},
#   {'all_phonemes': ['Y', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'YET'},
#   {'all_phonemes': ['Y', 'EH', 'T', 'IY'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'YETI'},
#   {'all_phonemes': ['Y', 'EH', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'YETT'},
#   {'all_phonemes': ['Y', 'EH', 'T', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'YETTA'},
#   {'all_phonemes': ['Y', 'OW', 'D', 'AH'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': 'YODA'},
#   {'all_phonemes': ['Y', 'AA', 'T'],
#    'numbers': ['1'],
#    'phonemes': ['T'],
#    'word': 'YOTT'},
#   {'all_phonemes': ['Y', 'UW', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "YOU'D"},
#   {'all_phonemes': ['Y', 'UH', 'D'],
#    'numbers': ['1'],
#    'phonemes': ['D'],
#    'word': "YOU'D"}]]

# %% [markdown]
# Some phonemes may not be separated by a space, or something. "ER0" Seems to be present, and I'm treating it like a vowel, but it's not.

# %%
partition(3, "1")
# Out:
# ['1']

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synsets('HEAD')
# Out:
# [Synset('head.n.01'),
#  Synset('head.n.02'),
#  Synset('mind.n.01'),
#  Synset('head.n.04'),
#  Synset('head.n.05'),
#  Synset('head.n.06'),
#  Synset('head.n.07'),
#  Synset('fountainhead.n.02'),
#  Synset('head.n.09'),
#  Synset('head.n.10'),
#  Synset('head.n.11'),
#  Synset('capitulum.n.01'),
#  Synset('principal.n.02'),
#  Synset('head.n.14'),
#  Synset('head.n.15'),
#  Synset('promontory.n.01'),
#  Synset('head.n.17'),
#  Synset('head.n.18'),
#  Synset('forefront.n.01'),
#  Synset('pass.n.09'),
#  Synset('headway.n.02'),
#  Synset('point.n.20'),
#  Synset('question.n.02'),
#  Synset('heading.n.01'),
#  Synset('head.n.25'),
#  Synset('head.n.26'),
#  Synset('read/write_head.n.01'),
#  Synset('head.n.28'),
#  Synset('head.n.29'),
#  Synset('head.n.30'),
#  Synset('head.n.31'),
#  Synset('drumhead.n.01'),
#  Synset('oral_sex.n.01'),
#  Synset('head.v.01'),
#  Synset('head.v.02'),
#  Synset('lead.v.04'),
#  Synset('head.v.04'),
#  Synset('steer.v.01'),
#  Synset('head.v.06'),
#  Synset('head.v.07'),
#  Synset('head.v.08'),
#  Synset('head.v.09')]

# %%
[x.pos() for x in wn.synsets('HEAD')]
# Out:
# [u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'n',
#  u'v',
#  u'v',
#  u'v',
#  u'v',
#  u'v',
#  u'v',
#  u'v',
#  u'v',
#  u'v']

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
2 + 2
# Out:
# 4
